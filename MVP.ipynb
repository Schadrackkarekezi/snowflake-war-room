# %%
import pandas as pd

# %%
dfr = pd.read_csv('data/analyst_ratings.csv')
dfcm = pd.read_csv("data/company_master.csv")
df_pf = pd.read_csv("data/data_peer_financial_metrics.csv")
df_pnews = pd.read_csv("data/data_peer_news_snippets.csv")
ea_t  = pd.read_csv("data/earnings_transcripts.csv")
sn_m = pd.read_csv("data/snowflake_ir_metrics.csv")
sn_p = pd.read_csv("data/snowflake_press_releases.csv")
sn_sec = pd.read_csv("data/snowflake_sec_filings.csv")

# %%
ea_t
# Out:
#      ID           COMPANY TICKER  \
# 0     1    Teradata Corp.    TDC
# 1   101     Datadog, Inc.   DDOG
# 2     2   Snowflake, Inc.   SNOW
# 3   201    Alphabet, Inc.  GOOGL
# 4   102    Alphabet, Inc.  GOOGL
# 5   301     MongoDB, Inc.    MDB
# 6     3   Snowflake, Inc.   SNOW
# 7     4  Amazon.com, Inc.   AMZN
# 8   103   Snowflake, Inc.   SNOW
# 9   104     Datadog, Inc.   DDOG
# 10  105     MongoDB, Inc.    MDB
# 11  302  Amazon.com, Inc.   AMZN
# 12    5   Snowflake, Inc.   SNOW
# 13  401   Microsoft Corp.   MSFT
# 14  202   Microsoft Corp.   MSFT
# 15  402    Alphabet, Inc.  GOOGL
# 16    6     MongoDB, Inc.    MDB
# 17    7    Teradata Corp.    TDC
# 18    8  Amazon.com, Inc.   AMZN
# 19  106   Snowflake, Inc.   SNOW
# 20  501     MongoDB, Inc.    MDB
# 21    9    Alphabet, Inc.  GOOGL
# 22  203   Microsoft Corp.   MSFT
# 23  502   Snowflake, Inc.   SNOW
# 24  403     Datadog, Inc.   DDOG
# 25  204     Datadog, Inc.   DDOG
# 26  404   Microsoft Corp.   MSFT
# ...

# %%
ea_t[['TRANSCRIPT_TEXT', 'SYNOPSIS']]
# Out:
#                                       TRANSCRIPT_TEXT  \
# 0   Corrected Transcript\n06-May-2025\nTeradata Co...
# 1   Corrected Transcript\n06-Nov-2025\nDatadog, In...
# 2   Corrected Transcript\n26-Feb-2025\nSnowflake, ...
# 3   Corrected Transcript\n29-Oct-2025\nAlphabet, I...
# 4   Corrected Transcript\n23-Jul-2025\nAlphabet, I...
# 5   Corrected Transcript\n04-Jun-2025\nMongoDB, In...
# 6   Corrected Transcript\n08-Sep-2025\nSnowflake, ...
# 7   Corrected Transcript\n06-Feb-2025\nAmazon.com,...
# 8   Corrected Transcript\n03-Dec-2025\nSnowflake, ...
# 9   Corrected Transcript\n06-May-2025\nDatadog, In...
# 10  Corrected Transcript\n05-Mar-2025\nMongoDB, In...
# 11  Corrected Transcript\n01-May-2025\nAmazon.com,...
# 12  Corrected Transcript\n21-May-2025\nSnowflake, ...
# 13  Corrected Transcript\n30-Apr-2025\nMicrosoft C...
# 14  Corrected Transcript\n30-Jul-2025\nMicrosoft C...
# 15  Corrected Transcript\n04-Feb-2025\nAlphabet, I...
# ...

# %%
ea_t['SYNOPSIS']
# Out:
# 0     Here's a comprehensive synopsis of Teradata's ...
# 1     Here's a structured synopsis of Datadog's Q3 2...
# 2     Here's a comprehensive synopsis of Snowflake's...
# 3     Based on the provided transcript excerpt, here...
# 4     Based on the provided transcript excerpt, here...
# 5     Here's a comprehensive synopsis of MongoDB's Q...
# 6     Based on the provided transcript excerpt, whic...
# 7     Here's a comprehensive synopsis of Amazon's Q4...
# 8     Here's a structured synopsis of Snowflake's Q3...
# 9     Here's a structured synopsis of Datadog's Q1 2...
# 10    Here's a structured synopsis of MongoDB's Q4 2...
# 11    Here's a structured synopsis of Amazon's Q1 20...
# 12    Here's a structured synopsis of Snowflake's Q1...
# 13    Based on the provided transcript excerpt, here...
# 14    Here's a structured synopsis of Microsoft's Q4...
# 15    Based on the provided transcript excerpt, here...
# 16    Here's a structured synopsis of MongoDB's Q2 2...
# ...
